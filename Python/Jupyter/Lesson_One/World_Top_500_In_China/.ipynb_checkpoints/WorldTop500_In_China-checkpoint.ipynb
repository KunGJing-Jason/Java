# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font = 'Microsoft YaHei',font_scale = 1.3)

from pyecharts import options as opts
from pyecharts.charts import Bar,Map,WordCloud,Grid,Pie
from pyecharts.faker import Faker
from pyecharts.globals import ThemeType

from warnings import filterwarnings
filterwarnings('ignore')
from pyecharts import options as opts
from pyecharts.charts import Map
from pyecharts.faker import Faker
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17232\4245085832.py in <module>
#       5 sns.set(font = 'Microsoft YaHei',font_scale = 1.3)
#       6
# ----> 7 from pyecharts import options as opts
#       8 from pyecharts.charts import Bar,Map,WordCloud,Grid,Pie
#       9 from pyecharts.faker import Faker
#
# ModuleNotFoundError: No module named 'pyecharts'

# %%
# 获取数据
data = pd.read_excel(r'C:\Users\32183\Desktop\MyCode\Python\Jupyter\Lesson_One\World_Top_500_In_China\Top500.xlsx')
data.shape

# %%
data['营业收入(百万美元)'] = data['营业收入(百万美元)'].str.replace(',','').astype('float')

# %%
nameMap = {
    'China':'中国'
}

# %%
x_data = data['字段2'].value_counts().index.tolist()
y_data = data['字段2'].value_counts().values.tolist()

# %%
c = (
    Map()
    .add('', [list(z) for z in zip(x_data, y_data)], "china")
    .set_global_opts(title_opts=opts.TitleOpts(title="中国世界500强分布"),visualmap_opts=opts.VisualMapOpts( max_=data['字段2'].value_counts().max(),min_ = data['字段2'].value_counts().min(),
                                                        is_piecewise=False
                                                   ))
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
)
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min', 'china':'https://assets.pyecharts.org/assets/v5/maps/china'
#         }
#     });
# </script>
#
#         <div id="c3bf7bb2d5004c85b82db58e2ac2fcdf" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_c3bf7bb2d5004c85b82db58e2ac2fcdf = echarts.init(
#                     document.getElementById('c3bf7bb2d5004c85b82db58e2ac2fcdf'), 'white', {renderer: 'canvas'});
#                 var option_c3bf7bb2d5004c85b82db58e2ac2fcdf = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
#         "#ee6666",
#         "#73c0de",
#         "#3ba272",
#         "#fc8452",
#         "#9a60b4",
#         "#ea7ccc"
#     ],
#     "series": [
#         {
#             "type": "map",
#             "label": {
#                 "show": false,
#                 "margin": 8
#             },
#             "map": "china",
#             "data": [
#                 {
#                     "name": "\u5317\u4eac\u5e02",
#                     "value": 60
#                 },
#                 {
#                     "name": "\u5e7f\u4e1c\u7701",
#                     "value": 16
#                 },
#                 {
#                     "name": "\u4e0a\u6d77\u5e02",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u9999\u6e2f\u7279\u522b\u884c\u653f\u533a",
#                     "value": 9
#                 },
#                 {
#                     "name": "\u53f0\u6e7e\u7701",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u6d59\u6c5f\u7701",
#                     "value": 8
#                 },
#                 {
#                     "name": "\u798f\u5efa\u7701",
#                     "value": 6
#                 },
#                 {
#                     "name": "\u5c71\u4e1c\u7701",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u5c71\u897f\u7701",
#                     "value": 5
#                 },
#                 {
#                     "name": "\u6c5f\u82cf\u7701",
#                     "value": 4
#                 },
#                 {
#                     "name": "\u65b0\u7586\u7ef4\u543e\u5c14\u81ea\u6cbb\u533a",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6cb3\u5317\u7701",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u5b89\u5fbd\u7701",
#                     "value": 2
#                 },
#                 {
#                     "name": "\u6e56\u5317\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5409\u6797\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u6c5f\u897f\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u7518\u8083\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u8fbd\u5b81\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u5e7f\u897f\u7701",
#                     "value": 1
#                 },
#                 {
#                     "name": "\u4e91\u5357\u7701",
#                     "value": 1
#                 }
#             ],
#             "roam": true,
#             "aspectScale": 0.75,
#             "nameProperty": "name",
#             "selectedMode": false,
#             "zoom": 1,
#             "mapValueCalculation": "sum",
#             "showLegendSymbol": true,
#             "emphasis": {},
#             "rippleEffect": {
#                 "show": true,
#                 "brushType": "stroke",
#                 "scale": 2.5,
#                 "period": 4
#             }
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 ""
#             ],
#             "selected": {
#                 "": true
#             },
#             "show": true,
#             "padding": 5,
#             "itemGap": 10,
#             "itemWidth": 25,
#             "itemHeight": 14,
#             "backgroundColor": "transparent",
#             "borderColor": "#ccc",
#             "borderWidth": 1,
#             "borderRadius": 0,
#             "pageButtonItemGap": 5,
#             "pageButtonPosition": "end",
#             "pageFormatter": "{current}/{total}",
#             "pageIconColor": "#2f4554",
#             "pageIconInactiveColor": "#aaa",
#             "pageIconSize": 15,
#             "animationDurationUpdate": 800,
#             "selector": false,
#             "selectorPosition": "auto",
#             "selectorItemGap": 7,
#             "selectorButtonGap": 10
#         }
#     ],
#     "tooltip": {
#         "show": true,
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "showContent": true,
#         "alwaysShowContent": false,
#         "showDelay": 0,
#         "hideDelay": 100,
#         "enterable": false,
#         "confine": false,
#         "appendToBody": false,
#         "transitionDuration": 0.4,
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "padding": 5,
#         "order": "seriesAsc"
#     },
#     "title": [
#         {
#             "show": true,
#             "text": "\u4e2d\u56fd\u4e16\u754c500\u5f3a\u5206\u5e03",
#             "target": "blank",
#             "subtarget": "blank",
#             "padding": 5,
#             "itemGap": 10,
#             "textAlign": "auto",
#             "textVerticalAlign": "auto",
#             "triggerEvent": false
#         }
#     ],
#     "visualMap": {
#         "show": true,
#         "type": "continuous",
#         "min": 1,
#         "max": 60,
#         "inRange": {
#             "color": [
#                 "#50a3ba",
#                 "#eac763",
#                 "#d94e5d"
#             ]
#         },
#         "calculable": true,
#         "inverse": false,
#         "splitNumber": 5,
#         "hoverLink": true,
#         "orient": "vertical",
#         "padding": 5,
#         "showLabel": true,
#         "itemWidth": 20,
#         "itemHeight": 140,
#         "borderWidth": 0
#     }
# };
#                 chart_c3bf7bb2d5004c85b82db58e2ac2fcdf.setOption(option_c3bf7bb2d5004c85b82db58e2ac2fcdf);
#         });
#     </script>
